# %% [markdown]
# # Part II - (Ford GoBike Data Analysis)
# ## by (Iniobong Nwa)

# %% [markdown]
# >**Before you start**: You must have the README.md file ready that include a summary of main findings that reflects on the steps taken during the data exploration (Part I notebook). The README.md file should also describes the key insights that will be conveyed by the explanatory slide deck (Part II  outcome)
#
#
#
# ## Investigation Overview
#
# >The Ford Gobike dataset contains information about individual rides made in a bike sharing company. This dataset originally contained 183412 rows and 16 columns, and after cleaning we were left with 174952 columns and 23 rows as some rows were dropped and new columns were created.
#
# > Over 70 percent of the users are males.
# > 90.5% of users are subscribers and 9.5% are customers.
# > The highest number of rides were recorded on Thurday and the least number of rides were recorded on Saturday and Sunday, 8.2% and 8.3% respectively.
# > The most number of bike usage was recorded at 8am-9am and 5pm-6pm.
#
#
# ## Dataset Overview
#
# > I cleaned the Ford Gobike dataset by dropping columns that contianed missing values. I also converting the columns with time values from integers to datetime datatypes and I converted columns like user type, bike sharing and member gender to categorical datatypes.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
# load in the dataset into a pandas dataframe
df_bike = pd.read_csv('df_bike.csv')

# %% [markdown]
# > Note that the above cells have been set as "Skip"-type slides. That means
# that when the notebook is rendered as http slides, those cells won't show up.

# %% [markdown]
# ## (Visualization 1)
#
# > This visualization shows the number of daily rides for the week, with the most rides recorded on Thursdays and the least recorded on Saturdays and Sundays.

# %%
base_color = sb.color_palette()[0]
days_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday','Friday','Saturday', 'Sunday']
plt.figure(figsize =[15,6])
sb.countplot(data= df_bike , x='start_day' , color= base_color, order= days_order)
plt.title('Bike ride most popular days', fontsize = 16, fontweight='bold')
plt.ylabel('Number of Bike trips', fontsize = 15)
plt.xlabel('Bike Ride start days', fontsize= 15)
plt.title('Number of Daily Bike Rides', fontsize=14, fontweight='bold')
plt.xlabel('Days');
days_count = df_bike['start_day'].value_counts()
total_trips= days_count.sum()
plt.yticks(size=13); 
locs, labels = plt.xticks( size=14); 
for loc, label in zip(locs, labels):
    count = days_count[label.get_text()]
    string = '{:0.1f}%'.format(100*count/total_trips)
    plt.text(loc, count-10000, string, ha = 'center', color = 'white',fontsize = 13)

# %% [markdown]
# ## (Visualization 2)
#
# > This visualisations show the relationships between days of the week and bike sharing for all trips. Non-bike sharing trips had the most number of trips everyday of the week and bike sharers had fewer number of trips.

# %%
plt.figure(figsize = [9,6])
days_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday','Friday','Saturday', 'Sunday']
sb.countplot(data= df_bike, x = 'start_day', hue = 'bike_share_for_all_trip', order= days_order)
plt.title('Daily Trip Duration for Bike sharing', fontsize=14, fontweight='bold')
plt.ylabel('Trip Duration (Secs)')
plt.xlabel('Days of the week', fontsize = 14)
plt.show()

# %% [markdown]
# ## (Visualization 3)
#
# > This plot shows the relationship between days of the week, bike sharing and the average duration of trips. The longest duration of trips were taken by those who opted to bike sharing everyday of the week and shorter trips were recorded by non-bike sharers, but recorded longer durations during the weekends.

# %%
fig = plt.figure(figsize = [12,12])
base_color = sb.color_palette()[0]
days_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday','Friday','Saturday', 'Sunday']
ax = sb.pointplot(data = df_bike, x ='start_day', y = 'duration_sec', hue = 'bike_share_for_all_trip', 
            color= base_color, linestyles = '',order=days_order, dodge = 0.4)
plt.title('Trip Duration across days of the week and Bike sharing', fontsize=14, fontweight='bold')
plt.ylabel('Trip Duration (Secs)')
plt.xlabel('Days', fontsize = 14)
ax.set_yticklabels([],minor = True)
plt.show()

# %% [markdown]
# ### Generate Slideshow
# Once you're ready to generate your slideshow, use the `jupyter nbconvert` command to generate the HTML slide show.

# %%
# !jupyter nbconvert --to slides FordGoBike.ipynb
# Out:
# [NbConvertApp] Converting notebook FordGoBike.ipynb to slides
# [NbConvertApp] Writing 378394 bytes to FordGoBike.slides.html

# %% [markdown]
# > In the classroom workspace, the generated HTML slideshow will be placed in the home folder.
#
# > In local machines, the command above should open a tab in your web browser where you can scroll through your presentation. Sub-slides can be accessed by pressing 'down' when viewing its parent slide. Make sure you remove all of the quote-formatted guide notes like this one before you finish your presentation! At last, you can stop the Kernel.

# %% [markdown]
# ### Submission
# If you are using classroom workspace, you can choose from the following two ways of submission:
#
# 1. **Submit from the workspace**. Make sure you have removed the example project from the /home/workspace directory. You must submit the following files:
#    - Part_I_notebook.ipynb
#    - Part_I_notebook.html or pdf
#    - Part_II_notebook.ipynb
#    - Part_I_slides.html
#    - README.md
#    - dataset (optional)
#
#
# 2. **Submit a zip file on the last page of this project lesson**. In this case, open the Jupyter terminal and run the command below to generate a ZIP file.
# ```bash
# zip -r my_project.zip .
# ```
# The command abobve will ZIP every file present in your /home/workspace directory. Next, you can download the zip to your local, and follow the instructions on the last page of this project lesson.
